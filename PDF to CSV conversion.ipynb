# %% [markdown]
# # Import the libraries

# %%
import tabula as tb
import pandas as pd

# %% [markdown]
# # Converting Pdf to CSV

# %%
data = tb.read_pdf("hdfc.pdf", pages="all", encoding='ISO-8859-1', stream=True, area=[2989.875, 1000.75,790.75, 961], guess=False)
df = tb.convert_into("hdfc.pdf", "Generatehdfc1.csv", pages="all", output_format="csv")

# %% [markdown]
# # Reading CSV file

# %%
df = pd.read_csv("Generatehdfc1.csv")
df.head(50)
df
# Out:
#          Date                                 Narration      Chq./Ref.No.  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004010
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020294
# 2         NaN  ETBANK, MUM-HDFCR52022020294165454-FOR O            165454
# 3         NaN                                        JS               NaN
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  AXTB220332807357
# ..        ...                                       ...               ...
# 107       NaN                                612,066.50                45
# 108       NaN           Generated On: 22-Feb-2022 14:58     Generated By:
# 109       NaN                                       NaN         135588024
# 110       NaN                                       NaN               NaN
# 111       NaN                                       NaN               NaN
#
#      Value Dt                                  Withdrawal Amt. Deposit Amt.  \
# 0    01/02/22                                        10,000.00          NaN
# 1    02/02/22                                       200,000.00          NaN
# 2         NaN                                              NaN          NaN
# 3         NaN                                              NaN          NaN
# 4    02/02/22                                              NaN   973,415.00
# ..        ...                                              ...          ...
# 107         6                        8,312,802.00 8,495,290.00   794,554.50
# 108       NaN                      Requesting Branch Code: NET          NaN
# 109       NaN                                              NaN          NaN
# 110       NaN  This is a computer generated statement and does          NaN
# 111       NaN                           not require signature.          NaN
#
#     Closing Balance
# 0        602,066.50
# 1        402,066.50
# 2               NaN
# 3               NaN
# 4      1,375,481.50
# ..              ...
# 107             NaN
# 108             NaN
# 109             NaN
# 110             NaN
# 111             NaN
#
# [112 rows x 7 columns]

# %% [markdown]
# # Rename the columns

# %%
df1 = df.drop_duplicates()
df.shape
df.rename(columns={"Deposit Amt.":"Credit", "Withdrawal Amt.":"Debit"}, inplace=True)
df
# Out:
#          Date                                 Narration      Chq./Ref.No.  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004010
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020294
# 2         NaN  ETBANK, MUM-HDFCR52022020294165454-FOR O            165454
# 3         NaN                                        JS               NaN
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  AXTB220332807357
# ..        ...                                       ...               ...
# 107       NaN                                612,066.50                45
# 108       NaN           Generated On: 22-Feb-2022 14:58     Generated By:
# 109       NaN                                       NaN         135588024
# 110       NaN                                       NaN               NaN
# 111       NaN                                       NaN               NaN
#
#      Value Dt                                            Debit      Credit  \
# 0    01/02/22                                        10,000.00         NaN
# 1    02/02/22                                       200,000.00         NaN
# 2         NaN                                              NaN         NaN
# 3         NaN                                              NaN         NaN
# 4    02/02/22                                              NaN  973,415.00
# ..        ...                                              ...         ...
# 107         6                        8,312,802.00 8,495,290.00  794,554.50
# 108       NaN                      Requesting Branch Code: NET         NaN
# 109       NaN                                              NaN         NaN
# 110       NaN  This is a computer generated statement and does         NaN
# 111       NaN                           not require signature.         NaN
#
#     Closing Balance
# 0        602,066.50
# 1        402,066.50
# 2               NaN
# 3               NaN
# 4      1,375,481.50
# ..              ...
# 107             NaN
# 108             NaN
# 109             NaN
# 110             NaN
# 111             NaN
#
# [112 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date               61
# Narration           3
# Chq./Ref.No.       50
# Value Dt           59
# Debit              62
# Credit             99
# Closing Balance    66
# dtype: int64

# %%
df3 = df.fillna(0)

# %% [markdown]
# # Removing unwanted columns

# %%
df4 = df3.drop(['Chq./Ref.No.','Value Dt','Closing Balance'], axis=1)
# we can use del function also to delete columns
df4
# Out:
#          Date                                 Narration  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N
# 2           0  ETBANK, MUM-HDFCR52022020294165454-FOR O
# 3           0                                        JS
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB
# ..        ...                                       ...
# 107         0                                612,066.50
# 108         0           Generated On: 22-Feb-2022 14:58
# 109         0                                         0
# 110         0                                         0
# 111         0                                         0
#
#                                                Debit      Credit
# 0                                          10,000.00           0
# 1                                         200,000.00           0
# 2                                                  0           0
# 3                                                  0           0
# 4                                                  0  973,415.00
# ..                                               ...         ...
# 107                        8,312,802.00 8,495,290.00  794,554.50
# 108                      Requesting Branch Code: NET           0
# 109                                                0           0
# 110  This is a computer generated statement and does           0
# 111                           not require signature.           0
#
# [112 rows x 4 columns]

# %% [markdown]
# # Rearrange the columns

# %%
clist = list(df4.columns)
clist = ['Date', 'Narration', 'Credit', 'Debit']
df4 = df4[clist]
df5 = df4.head(105)
df5
# Out:
#          Date                                 Narration      Credit  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD           0
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N           0
# 2           0  ETBANK, MUM-HDFCR52022020294165454-FOR O           0
# 3           0                                        JS           0
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  973,415.00
# ..        ...                                       ...         ...
# 100  22/02/22  NEFT DR-UBIN0545627-SHAIK MAHABOOB-NETBA  888,017.50
# 101         0            NK, MUM-N053221843693105-JAN22           0
# 102  22/02/22  NEFT DR-SBIN0021495-SRI VENKATESHWARA GA  794,554.50
# 103         0  S AGENCY NEW-NETBANK, MUM-N0532218437067           0
# 104         0                                  24-JAN22           0
#
#           Debit
# 0     10,000.00
# 1    200,000.00
# 2             0
# 3             0
# 4             0
# ..          ...
# 100   82,170.00
# 101           0
# 102   93,463.00
# 103           0
# 104           0
#
# [105 rows x 4 columns]

# %% [markdown]
# # Converting into the CSV

# %%
df5.to_csv('GenerateTo.csv')

# %%
#Trying to join the rows of Narration


# aggregation_functions = {'Narration': 'first', 'Credit': 'first', 'Debit': 'first'}
# df_new = df5.groupby('Date')['Narration'].apply(' '.join).reset_index()
yourdf=df.groupby('Date',as_index=False).agg({'Narration':','.join,'Credit':'first', 'Debit':'first'})
yourdf
# Out:
#         Date                                          Narration        Credit  \
# 0   01/02/22            ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD          None
# 1   02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N,NEFT ...    973,415.00
# 2   03/02/22  09111000010612-TPT-SALARY FOR THE MONTH,RTGS D...          None
# 3   04/02/22             50200048665631-TPT-DEC21-P N LOGISTICS          None
# 4   05/02/22  IMPS-203611479566-TATA CAPITAL FINANCI-H,00600...          1.00
# 5   06/02/22           EMI 117863108 CHQ S117863108110 02221178          None
# 6   08/02/22  NEFT CR-IBKL0NEFT01-CORRTECH INTERNATION,FT - ...  1,434,500.00
# 7   09/02/22  IMPS-204001305849-MIHIRKUMAR PRAFULCHAND,POS 4...          None
# 8   10/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N,NEFT ...          None
# 9   11/02/22           NEFT DR-BKID0002040-TVASHTA INFRASTRUCTU          None
# 10  14/02/22  NEFT DR-CBIN0283326-KOPPOLU PRANATHI-NET,NEFT ...          None
# 11  15/02/22  SI HGA4P1181A0042883927 SOUTHER-15/02/22,SI HG...  2,375,768.00
# 12  16/02/22  IMPS-204710309862-MAHIMA CON SANJEEV-UTI,SI HG...          None
# 13  17/02/22           IMPS-204813112035-PRAJI PROJECTS LLP-BAR          None
# 14  18/02/22  RTGS CR-BARB0VJTTEJ-PRAJI PROJECTS LLP-P,SELF ...  1,300,000.00
# 15  20/02/22           GST/BANK REFERENCE NO: R2205132716518/CI          None
# 16  21/02/22           IMPS-205213376414-MIHIRKUMAR PRAFULCHAND          None
# 17  22/02/22  CHQ PAID-MICR CTS-MU-AXIS BANK LTD BUSIN,RTGS ...  1,285,335.50
#
#          Debit
# 0    10,000.00
# 1   200,000.00
# 2   202,500.00
# 3    50,225.00
# 4    15,000.00
# 5    86,663.00
# 6   356,985.00
# 7    10,000.00
# 8   600,000.00
# 9    26,000.00
# 10   10,500.00
# 11    1,278.00
# 12  100,000.00
# 13   10,000.00
# 14  134,000.00
# 15  367,286.00
# 16   20,000.00
# 17   35,653.00
