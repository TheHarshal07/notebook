# %%
import tabula as tb
import pandas as pd

# %%
data = tb.read_pdf("hdfc.pdf", pages="all")
df = tb.convert_into("hdfc.pdf", "Generatehdfc.csv", pages="all", output_format="csv")

# %%
df = pd.read_csv("Generatehdfc.csv")
df.head(50)
# data = df.iloc[:,:-1].values
# data
df
# Out:
#          Date                                 Narration      Chq./Ref.No.  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004010
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020294
# 2         NaN  ETBANK, MUM-HDFCR52022020294165454-FOR O            165454
# 3         NaN                                        JS               NaN
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  AXTB220332807357
# ..        ...                                       ...               ...
# 107       NaN                                612,066.50                45
# 108       NaN           Generated On: 22-Feb-2022 14:58     Generated By:
# 109       NaN                                       NaN         135588024
# 110       NaN                                       NaN               NaN
# 111       NaN                                       NaN               NaN
#
#      Value Dt                                  Withdrawal Amt. Deposit Amt.  \
# 0    01/02/22                                        10,000.00          NaN
# 1    02/02/22                                       200,000.00          NaN
# 2         NaN                                              NaN          NaN
# 3         NaN                                              NaN          NaN
# 4    02/02/22                                              NaN   973,415.00
# ..        ...                                              ...          ...
# 107         6                        8,312,802.00 8,495,290.00   794,554.50
# 108       NaN                      Requesting Branch Code: NET          NaN
# 109       NaN                                              NaN          NaN
# 110       NaN  This is a computer generated statement and does          NaN
# 111       NaN                           not require signature.          NaN
#
#     Closing Balance
# 0        602,066.50
# 1        402,066.50
# 2               NaN
# 3               NaN
# 4      1,375,481.50
# ..              ...
# 107             NaN
# 108             NaN
# 109             NaN
# 110             NaN
# 111             NaN
#
# [112 rows x 7 columns]

# %%
df1 = df.drop_duplicates()
df.shape
df.rename(columns={"Deposit Amt.":"Credit", "Withdrawal Amt.":"Debit"}, inplace=True)
df
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_6208\4265306988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"Deposit Amt.":"Credit", "Withdrawal Amt.":"Debit"}, inplace=True)
#          Date                                 Narration      Chq./Ref.No.  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004010
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020294
# 2         NaN  ETBANK, MUM-HDFCR52022020294165454-FOR O            165454
# 3         NaN                                        JS               NaN
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  AXTB220332807357
# ..        ...                                       ...               ...
# 107       NaN                                612,066.50                45
# 108       NaN           Generated On: 22-Feb-2022 14:58     Generated By:
# 109       NaN                                       NaN         135588024
# 110       NaN                                       NaN               NaN
# 111       NaN                                       NaN               NaN
#
#      Value Dt                                            Debit      Credit  \
# 0    01/02/22                                        10,000.00         NaN
# 1    02/02/22                                       200,000.00         NaN
# 2         NaN                                              NaN         NaN
# 3         NaN                                              NaN         NaN
# 4    02/02/22                                              NaN  973,415.00
# ..        ...                                              ...         ...
# 107         6                        8,312,802.00 8,495,290.00  794,554.50
# 108       NaN                      Requesting Branch Code: NET         NaN
# 109       NaN                                              NaN         NaN
# 110       NaN  This is a computer generated statement and does         NaN
# 111       NaN                           not require signature.         NaN
#
#     Closing Balance
# 0        602,066.50
# 1        402,066.50
# 2               NaN
# 3               NaN
# 4      1,375,481.50
# ..              ...
# 107             NaN
# 108             NaN
# 109             NaN
# 110             NaN
# 111             NaN
#
# [109 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# Date               58
# Narration           3
# Chq./Ref.No.       47
# Value Dt           56
# Withdrawal Amt.    59
# Deposit Amt.       96
# Closing Balance    63
# dtype: int64

# %%
df3 = df.fillna(0)
df3.head(50)
# Out:
#         Date                                 Narration      Chq./Ref.No.  \
# 0   01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004010
# 1   02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020294
# 2          0  ETBANK, MUM-HDFCR52022020294165454-FOR O            165454
# 3          0                                        JS                 0
# 4   02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  AXTB220332807357
# 5          0   PRAJI-BPR000307051007 PRAJI PROJECTS LL                 0
# 6          0                        P-AXTB220332807357                 0
# 7   03/02/22   09111000010612-TPT-SALARY FOR THE MONTH  0000000256197913
# 8          0               OF JANUARY-ZALA MAHESHKUMAR                 0
# 9   03/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N  HDFCR52022020394
# 10         0  ETBANK, MUM-HDFCR52022020394506364-SRIYA            506364
# 11         0                                    METALS                 0
# 12  03/02/22  IB FUNDS TRANSFER DR-59209825024478-PRAJ  MB03163751947T28
# 13         0                            I PROJECTS LLP                 0
# 14  04/02/22    50200048665631-TPT-DEC21-P N LOGISTICS  0000000395646705
# 15  05/02/22  IMPS-203611479566-TATA CAPITAL FINANCI-H  0000203611479566
# 16         0   DFC-XXXXXXXXXX2683-TATA CAPITAL LIMITED                 0
# 17  05/02/22                   00600310012683-51502116  0000202057004659
# 18  05/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD  0000000000004810
# 19  05/02/22  NEFT DR-UBIN0542261-C SUGUNAKAR REDDY-NE  N036221821489361
# 20         0         TBANK, MUM-N036221821489361-SEP21                 0
# 21  05/02/22  RTGS DR-PUNB0211120-MS DURGA EARTH MOVER  HDFCR52022020595
# 22         0  S-NETBANK, MUM-HDFCR52022020595005081-SE            005081
# 23         0                                       P21                 0
# 24  05/02/22  NEFT DR-SBIN0005917-BNR EARTH MOVERS-NET  N036221821522505
# 25         0          BANK, MUM-N036221821522505-SEP21                 0
# 31         0           0             0               0
# 32  05/02/22  300,000.00             0    2,013,676.50
# 33         0           0             0               0
# 34  05/02/22  576,121.00             0    1,437,555.50
# 35         0           0             0               0
# 36  06/02/22   86,663.00             0    1,350,892.50
# 37         0           0             0               0
# 38  08/02/22           0  1,434,500.00    2,785,392.50
# 39         0           0             0               0
# 40         0           0             0               0
# 41  08/02/22  356,985.00             0    2,428,407.50
# 42         0           0             0               0
# 43  08/02/22  500,000.00             0    1,928,407.50
# 44         0           0             0               0
# 45  08/02/22  323,850.00             0    1,604,557.50
# 46         0           0             0               0
# 47  08/02/22  150,000.00             0    1,454,557.50
# 48         0           0             0               0
# 49  09/02/22   10,000.00             0    1,444,557.50

# %%
df4 = df3.drop(['Chq./Ref.No.','Value Dt','Closing Balance'], axis=1)
# we can del function also to delete columns
df4
# Out:
#          Date                                 Narration  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N
# 2           0  ETBANK, MUM-HDFCR52022020294165454-FOR O
# 3           0                                        JS
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB
# ..        ...                                       ...
# 107         0                                612,066.50
# 108         0           Generated On: 22-Feb-2022 14:58
# 109         0                                         0
# 110         0                                         0
# 111         0                                         0
#
#                                                Debit      Credit
# 0                                          10,000.00           0
# 1                                         200,000.00           0
# 2                                                  0           0
# 3                                                  0           0
# 4                                                  0  973,415.00
# ..                                               ...         ...
# 107                        8,312,802.00 8,495,290.00  794,554.50
# 108                      Requesting Branch Code: NET           0
# 109                                                0           0
# 110  This is a computer generated statement and does           0
# 111                           not require signature.           0
#
# [112 rows x 4 columns]

# %%
#Rearrange the columns
clist = list(df4.columns)
clist = ['Date', 'Narration', 'Credit', 'Debit']
df4 = df4[clist]
df4.head(105)
# Out:
#          Date                                 Narration      Credit  \
# 0    01/02/22   ATW-416021XXXXXX5125-E1AWAH01-AHMEDABAD           0
# 1    02/02/22  RTGS DR-BARB0VJTTEJ-PRAJI PROJECTS LLP-N           0
# 2           0  ETBANK, MUM-HDFCR52022020294165454-FOR O           0
# 3           0                                        JS           0
# 4    02/02/22  NEFT CR-UTIB0000245-BPR000307051007 DISB  973,415.00
# ..        ...                                       ...         ...
# 100  22/02/22  NEFT DR-UBIN0545627-SHAIK MAHABOOB-NETBA  888,017.50
# 101         0            NK, MUM-N053221843693105-JAN22           0
# 102  22/02/22  NEFT DR-SBIN0021495-SRI VENKATESHWARA GA  794,554.50
# 103         0  S AGENCY NEW-NETBANK, MUM-N0532218437067           0
# 104         0                                  24-JAN22           0
#
#           Debit
# 0     10,000.00
# 1    200,000.00
# 2             0
# 3             0
# 4             0
# ..          ...
# 100   82,170.00
# 101           0
# 102   93,463.00
# 103           0
# 104           0
#
# [105 rows x 4 columns]
